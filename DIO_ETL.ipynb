# %%
## Instalando Pandera
# !pip install pandera
# Out:
# ...
#      |████████████████████████████████| 162 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 234 kB 52.2 MB/s
# ...
#      |████████████████████████████████| 245 kB 39.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 45 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 48.6 MB/s
# ...
#   Created wheel for petl: filename=petl-1.7.4-py3-none-any.whl size=217001 sha256=e5b8210166eb601e2f7543b3d9c41d4b4580b756ac7be5dc7579b301787f6fac
#   Stored in directory: /root/.cache/pip/wheels/75/23/fb/a0e8e350a8718579b0cde55163df77b94de835d7d116388fa5
# ...
#   Created wheel for simpleeval: filename=simpleeval-0.9.10-py3-none-any.whl size=13769 sha256=f889250a6bf813c9031d7dc393ec2111b41917af6e9137d46a32bbad8b50bd90
#   Stored in directory: /root/.cache/pip/wheels/d4/aa/50/0b420d1eabad3c16a82368935c6a2050955bc3ee2a11ee4e06
# ...

# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
# 5              39807               39807  ...        17:53:00                   0
# 6              40215               40215  ...        18:40:00                   0
# 7              39707               39707  ...        12:30:00                   3
# 8              39156               39156  ...        23:15:00                   2
# 9              39711               39711  ...        20:00:00                   0
#
# [10 rows x 9 columns]

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,3)),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$') ,nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 4                 40324  ...                    0
# ...                 ...  ...                  ...
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [5752 rows x 9 columns]

# %%
## Limpando Colunas ##
## df.drop('codigo_ocorrencia1', inplace=True, axis=1)
## df.drop('codigo_ocorrencia3', inplace=True, axis=1)
## df.drop('codigo_ocorrencia4', inplace=True, axis=1)
## df.drop('ocorrencia_latitude', inplace=True, axis=1)
## df.drop('ocorrencia_longitude', inplace=True, axis=1)
## df.drop('ocorrencia_pais', inplace=True, axis=1)
## df.drop('investigacao_aeronave_liberada', inplace=True, axis=1)
## df.drop('investigacao_status', inplace=True, axis=1)
## df.drop('divulgacao_relatorio_numero', inplace=True, axis=1)
## df.drop('divulgacao_relatorio_publicado', inplace=True, axis=1)
## df.drop('divulgacao_dia_publicacao', inplace=True, axis=1)
## df.drop('total_aeronaves_envolvidas', inplace=True, axis=1)
## df.drop('ocorrencia_saida_pista', inplace=True, axis=1)

# %%
df.tail(10)
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 5742              79800  ...                    0
# 5743              79824  ...                    0
# 5744              79753  ...                    0
# 5745              79755  ...                    0
# 5746              79769  ...                    0
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [10 rows x 9 columns]

# %%
## Exibindo tipos de dados das colunas
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
## Testando função na coluna do tipo data
df.ocorrencia_dia.dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 5747    12
# 5748    12
# 5749    12
# 5750    12
# 5751    12
# Name: ocorrencia_dia, Length: 5752, dtype: int64
