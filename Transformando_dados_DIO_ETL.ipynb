# %%
## Instalando Pandera
# !pip install pandera
# Out:
# ...
#      |████████████████████████████████| 162 kB 14.6 MB/s
# ...
#      |████████████████████████████████| 234 kB 23.2 MB/s
# ...
#      |████████████████████████████████| 245 kB 21.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 45 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 636 kB 24.9 MB/s
# ...
#   Created wheel for petl: filename=petl-1.7.4-py3-none-any.whl size=217001 sha256=84f8a27eeddef32d4fa5f995b508740c5e95c16f43bf0fe82eff97e531f7cf0d
#   Stored in directory: /root/.cache/pip/wheels/75/23/fb/a0e8e350a8718579b0cde55163df77b94de835d7d116388fa5
# ...
#   Created wheel for simpleeval: filename=simpleeval-0.9.10-py3-none-any.whl size=13769 sha256=d0bda2983122fc5503ca92e6d43ecabebacb6ce03a54a269366a2d10cc8ae927
#   Stored in directory: /root/.cache/pip/wheels/d4/aa/50/0b420d1eabad3c16a82368935c6a2050955bc3ee2a11ee4e06
# ...

# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes = ['**', '***', '###!', '####', '****', '*****', 'NULL']
df = pd.read_csv("ocorrencia_2010_2020.csv", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
# 5              39807               39807  ...        17:53:00                   0
# 6              40215               40215  ...        18:40:00                   0
# 7              39707               39707  ...        12:30:00                   3
# 8              39156               39156  ...        23:15:00                   2
# 9              39711               39711  ...        20:00:00                   0
#
# [10 rows x 9 columns]

# %%
# Criando schema para validar dados
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,3), nullable=True),
        "ocorrencia_aerodromo": pa.Column(pa.String, nullable=True),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$') ,nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
# Validando dados de acordo com schema
schema.validate(df)
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 4                 40324  ...                    0
# ...                 ...  ...                  ...
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [5752 rows x 9 columns]

# %%
df.loc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# codigo_ocorrencia                         79844
# codigo_ocorrencia2                        79844
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                RIO DE JANEIRO
# ocorrencia_uf                                RJ
# ocorrencia_aerodromo                       SBJR
# ocorrencia_dia              2020-12-31 00:00:00
# ocorrencia_hora                        13:24:00
# total_recomendacoes                           0
# Name: 5751, dtype: object

# %%
df.loc[:, 'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
df['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
# Exibindo total de valores nulos
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# Exibindo linha com valores null, na coluna ocorrencia_uf
filtro = df.ocorrencia_uf.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 2227              49474  ...                    0
#
# [1 rows x 9 columns]

# %%
# Exibindo linha com valores null, na coluna ocorrencia_aerodromo
filtro = df.ocorrencia_aerodromo.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 3                 39527  ...                    0
# 5                 39807  ...                    0
# 7                 39707  ...                    3
# 9                 39711  ...                    0
# ...                 ...  ...                  ...
# 5741              79754  ...                    0
# 5744              79753  ...                    0
# 5745              79755  ...                    0
# 5748              79757  ...                    0
# 5750              79756  ...                    0
#
# [2349 rows x 9 columns]

# %%
# Exibindo linha com valores null, na coluna ocorrencia_hora
filtro = df.ocorrencia_hora.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 4100              78823  ...                    0
#
# [1 rows x 9 columns]

# %%
# ocorrencia com mais de 10 recomendações
filtro = df.total_recomendacoes > 10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 63                39992  ...                   11
# 326               42250  ...                   19
# 530               43471  ...                   11
# 727               44377  ...                   11
# 872               44796  ...                   23
# 884               44888  ...                   11
# 1062              45554  ...                   20
# 1972              47938  ...                   11
# 2795              52265  ...                   13
# 3930              66432  ...                   12
#
# [10 rows x 9 columns]

# %%
# cidade com ocorrencias com mais de 10 recomendações
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2795                SANTOS                   13
# 3930               VITÓRIA                   12

# %%
# cidade com ocorrencias do tipo: INCIDENTE GRAVE
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro, ['ocorrencia_cidade', 'ocorrencia_classificacao','total_recomendacoes']]
# Out:
#       ocorrencia_cidade ocorrencia_classificacao  total_recomendacoes
# 7              CANUTAMA          INCIDENTE GRAVE                    3
# 8              CASCAVEL          INCIDENTE GRAVE                    2
# 9         PARÁ DE MINAS          INCIDENTE GRAVE                    0
# 29             CURITIBA          INCIDENTE GRAVE                    2
# 35               PALMAS          INCIDENTE GRAVE                    0
# ...                 ...                      ...                  ...
# 5741       NOVA MARINGÁ          INCIDENTE GRAVE                    0
# 5744           GOIATUBA          INCIDENTE GRAVE                    0
# 5746      MANOEL URBANO          INCIDENTE GRAVE                    0
# 5748  LAGOA DA CONFUSÃO          INCIDENTE GRAVE                    0
# 5750          VICENTINA          INCIDENTE GRAVE                    0
#
# [737 rows x 3 columns]

# %%
# Filtrando ocorrencias do tipo: INCIDENTE GRAVE e o estado igual a SP
# Usando Condição: AND
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro & filtro2]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 136               40270  ...                    0
# 171               40620  ...                    0
# 219               41411  ...                    2
# 297               42289  ...                    0
# 314               42323  ...                    0
# ...                 ...  ...                  ...
# 5591              79540  ...                    0
# 5610              79566  ...                    0
# 5704              79739  ...                    0
# 5705              79705  ...                    0
# 5715              79718  ...                    0
#
# [137 rows x 9 columns]

# %%
# Filtrando ocorrencias do tipo: INCIDENTE GRAVE ou estado igual a SP
# Usando Condição: OR
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro | filtro2]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 7                 39707  ...                    3
# 8                 39156  ...                    2
# 9                 39711  ...                    0
# 11                40069  ...                    8
# 16                39809  ...                    0
# ...                 ...  ...                  ...
# 5744              79753  ...                    0
# 5746              79769  ...                    0
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5750              79756  ...                    0
#
# [1973 rows x 9 columns]

# %%
# Filtrando ocorrencias cuja classificação: 'INCIDENTE GRAVE' OR 'INCIDENTE' AND Estado igual a SP
# Usando Condição: OR e AND
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE','INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 16                39809  ...                    0
# 18                39828  ...                    0
# 26                39847  ...                    0
# 27                39768  ...                    0
# 33                39848  ...                    0
# ...                 ...  ...                  ...
# 5704              79739  ...                    0
# 5705              79705  ...                    0
# 5715              79718  ...                    0
# 5742              79800  ...                    0
# 5747              79804  ...                    0
#
# [985 rows x 9 columns]

# %%
# Ocorrencias cuja cidade começa com letra "C"
filtro1 = df.ocorrencia_cidade.str[0] == 'C' # startswith("C")
df.loc[filtro1]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 6                 40215  ...                    0
# 7                 39707  ...                    3
# 8                 39156  ...                    2
# 15                39315  ...                    0
# 20                40310  ...                    0
# ...                 ...  ...                  ...
# 5661              79649  ...                    0
# 5663              79652  ...                    0
# 5680              79683  ...                    0
# 5696              79692  ...                    0
# 5747              79804  ...                    0
#
# [825 rows x 9 columns]

# %%
# Ocorrencias cuja cidade termina com letra "A"
filtro1 = df.ocorrencia_cidade.str[-1] == 'A' # endswith("A")
df.loc[filtro1]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 7                 39707  ...                    3
# 12                40414  ...                    0
# 15                39315  ...                    0
# 25                39772  ...                    0
# 26                39847  ...                    0
# ...                 ...  ...                  ...
# 5738              79787  ...                    0
# 5739              79749  ...                    0
# 5743              79824  ...                    0
# 5744              79753  ...                    0
# 5750              79756  ...                    0
#
# [1556 rows x 9 columns]

# %%
# Ocorrencias cuja cidade termina com os caracteres "US"
filtro1 = df.ocorrencia_cidade.str[-2:] == 'US'
df.loc[filtro1]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 78                39916  ...                    2
# 100               40170  ...                    0
# 163               40575  ...                    0
# 174               40791  ...                    0
# 180               40834  ...                    0
# ...                 ...  ...                  ...
# 5606              79591  ...                    0
# 5691              79709  ...                    0
# 5707              79712  ...                    0
# 5730              79785  ...                    0
# 5731              79746  ...                    0
#
# [124 rows x 9 columns]

# %%
# Ocorrencias cuja cidade contem os caracteres "US"
filtro1 = df.ocorrencia_cidade.str.contains('US')
df.loc[filtro1]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 78                39916  ...                    2
# 100               40170  ...                    0
# 163               40575  ...                    0
# 174               40791  ...                    0
# 180               40834  ...                    0
# ...                 ...  ...                  ...
# 5691              79709  ...                    0
# 5707              79712  ...                    0
# 5730              79785  ...                    0
# 5731              79746  ...                    0
# 5748              79757  ...                    0
#
# [144 rows x 9 columns]

# %%
# Ocorrencias cuja cidade contem os caracteres "MA" ou "US"
filtro1 = df.ocorrencia_cidade.str.contains('MA|US')
df.loc[filtro1]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 7                 39707  ...                    3
# 13                39507  ...                    2
# 15                39315  ...                    0
# 35                39487  ...                    0
# 78                39916  ...                    2
# ...                 ...  ...                  ...
# 5739              79749  ...                    0
# 5741              79754  ...                    0
# 5745              79755  ...                    0
# 5746              79769  ...                    0
# 5748              79757  ...                    0
#
# [526 rows x 9 columns]

# %%
# Ocorrencias do ano de 2015
filtro1 = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro1]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 2996              52992  ...                    3
# 2997              52979  ...                    0
# 2998              53073  ...                    0
# 2999              53074  ...                    0
# 3000              52976  ...                    6
# ...                 ...  ...                  ...
# 3462              60632  ...                    0
# 3463              60600  ...                    0
# 3464              60642  ...                    0
# 3465              60631  ...                    2
# 3466              60649  ...                    0
#
# [471 rows x 9 columns]

# %%
# Ocorrencias do ano de 2015 e mês 12
## filtro1 = (df.ocorrencia_dia.dt.year == 2015) & (df.ocorrencia_dia.dt.month == 12)
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 3428              53573  ...                    0
# 3429              60601  ...                    0
# 3430              53634  ...                    0
# 3431              53636  ...                    0
# 3432              53575  ...                    0
# 3433              60637  ...                    0
# 3434              53625  ...                    3
# 3435              53626  ...                    1
# 3436              53628  ...                    1
# 3437              53629  ...                    0
# 3438              53631  ...                    0
# 3439              60636  ...                    0
# 3440              53627  ...                    0
# 3441              60604  ...                    0
# 3442              60611  ...                    0
# 3443              60613  ...                    0
# 3444              60629  ...                    0
# 3445              53630  ...                    0
# ...

# %%
# Ocorrencias do ano de 2015 e mês 12 e os dias entre 3 e 8
filtro_ano = df.ocorrencia_dia.dt.year == 2015
filtro_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia = (df.ocorrencia_dia.dt.day >= 3) & (df.ocorrencia_dia.dt.day <= 8)
df.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 3432              53575  ...                    0
# 3433              60637  ...                    0
# 3434              53625  ...                    3
# 3435              53626  ...                    1
# 3436              53628  ...                    1
# 3437              53629  ...                    0
# 3438              53631  ...                    0
# 3439              60636  ...                    0
#
# [8 rows x 9 columns]

# %%
# Unificando DATE com STRING
# Utilizamos "pd.to_datetime" para criar um datetime
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora         datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#    codigo_ocorrencia  ...  ocorrencia_dia_hora
# 0              40211  ...  2010-01-03 12:00:00
# 1              40349  ...  2010-01-03 11:05:00
# 2              40351  ...  2010-01-03 03:00:00
# 3              39527  ...  2010-01-04 17:30:00
# 4              40324  ...  2010-01-05 19:25:00
#
# [5 rows x 10 columns]

# %%
# Ocorrencias do ano de 2015 e mês 12 e os dias entre 3 e 8
filtro1 = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro2 = df.ocorrencia_dia_hora <= '2015-12-08 13:00:00'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  ...  ocorrencia_dia_hora
# 3433              60637  ...  2015-12-03 16:47:00
# 3434              53625  ...  2015-12-06 13:10:00
# 3435              53626  ...  2015-12-06 15:00:00
# 3437              53629  ...  2015-12-08 10:20:00
# 3439              60636  ...  2015-12-08 13:00:00
#
# [5 rows x 10 columns]

# %%
# ocorrencias do anor de 2015 e mês 03
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 3
df201503 = df.loc[filtro1 & filtro2]

# %%
df201503.head(5)
# Out:
#       codigo_ocorrencia  ...  ocorrencia_dia_hora
# 3086              53183  ...  2015-03-02 23:00:00
# 3087              53120  ...  2015-03-04 13:30:00
# 3088              53109  ...  2015-03-05 13:50:00
# 3089              53112  ...  2015-03-06 21:00:00
# 3090              53152  ...  2015-03-10 11:30:00
#
# [5 rows x 10 columns]

# %%
# Agrupando e contando dados
df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: codigo_ocorrencia, dtype: int64

# %%
# Agrupando e contando dados
df201503.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            5
# INCIDENTE          14
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %%
# Agrupando e exbibindo o tamanho, que não é alterado por valores nulos
df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
filtro1 = df.ocorrencia_dia.dt.year == 2010
filtro2 = df.ocorrencia_uf.isin(['SP', 'MG', 'ES', 'RJ'])
dfsudeste2010 = df.loc[filtro1 & filtro2]
dfsudeste2010
# Out:
#      codigo_ocorrencia  ...  ocorrencia_dia_hora
# 0                40211  ...  2010-01-03 12:00:00
# 2                40351  ...  2010-01-03 03:00:00
# 9                39711  ...  2010-01-10 20:00:00
# 11               40069  ...  2010-01-10 14:50:00
# 16               39809  ...  2010-01-15 15:00:00
# ..                 ...  ...                  ...
# 541              43722  ...  2010-12-23 11:00:00
# 544              43548  ...  2010-12-26 22:10:00
# 548              43724  ...  2010-12-29 12:00:00
# 550              43730  ...  2010-12-30 18:10:00
# 551              43975  ...  2010-12-30 14:28:00
#
# [228 rows x 10 columns]

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
dfsudeste2010.count()
# Out:
# codigo_ocorrencia           228
# codigo_ocorrencia2          228
# ocorrencia_classificacao    228
# ocorrencia_cidade           228
# ocorrencia_uf               228
# ocorrencia_aerodromo        127
# ocorrencia_dia              228
# ocorrencia_hora             228
# total_recomendacoes         228
# ocorrencia_dia_hora         228
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao', 'ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  MG                7
#                           RJ                9
#                           SP               24
# INCIDENTE                 ES                5
#                           MG               39
#                           RJ               52
#                           SP               74
# INCIDENTE GRAVE           MG                5
#                           RJ                4
#                           SP                9
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO           47
# SÃO PAULO                33
# GUARULHOS                18
# BELO HORIZONTE           17
# CAMPINAS                 13
# MACAÉ                    12
# CONFINS                   7
# UBERLÂNDIA                5
# VITÓRIA                   4
# JUIZ DE FORA              4
# SÃO JOSÉ DO RIO PRETO     3
# SÃO JOSÉ DOS CAMPOS       3
# MARÍLIA                   3
# ARARAQUARA                2
# MONTES CLAROS             2
# CAMPOS DOS GOYTACAZES     2
# DIVINÓPOLIS               2
# IPATINGA                  2
# ITANHAÉM                  2
# JUNDIAÍ                   2
# POÇOS DE CALDAS           2
# RIBEIRÃO PRETO            2
# SOROCABA                  2
# UBERABA                   2
# BAURU                     2
# AREALVA                   2
# BOITUVA                   1
# BOCAINA                   1
# BOM JESUS DO AMPARO       1
# BOM JESUS DO GALHO        1
# BEBEDOURO                 1
# BRAGANÇA PAULISTA         1
# ...

# %%
filtro1 = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
filtro2 = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  ...  ocorrencia_dia_hora
# 119              40190  ...  2010-04-06 02:35:00
# 274              41750  ...  2010-07-12 19:53:00
# 326              42250  ...  2010-08-12 12:26:00
#
# [3 rows x 10 columns]

# %%
# Soma do total de recomendações por cidade
dfsudeste2010.groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# AMERICANA                 0
# ARARAQUARA                0
# ARAÇATUBA                 0
# AREALVA                   0
# ARRAIAL DO CABO           0
# BAURU                     0
# BEBEDOURO                 0
# BELO HORIZONTE            2
# BOCAINA                   0
# BOITUVA                   1
# BOM JESUS DO AMPARO       0
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         9
# BROTAS                    0
# CAJOBI                    0
# CAMANDUCAIA               9
# CAMPINAS                  0
# CAMPOS DOS GOYTACAZES     0
# CASIMIRO DE ABREU         0
# CONFINS                   0
# COROMANDEL                0
# COSMÓPOLIS                0
# DIAMANTINA                0
# DIVINÓPOLIS               0
# GUARULHOS                 0
# IPATINGA                  0
# IPERÓ                     3
# ITANHAÉM                  1
# ITÁPOLIS                  0
# JUIZ DE FORA              0
# JUNDIAÍ                   7
# LINHARES                  0
# ...
